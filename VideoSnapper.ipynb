# %% [markdown]
# INSTRUCTIONS
#
# 1. Run this in Google CoLab
#
# 2. find a good video on youTube
#
# 3. download an app called 4k video downloader, and use it to save the video. it's free. choose the 720HR option if possible so the are consistent
#
# 4. repeat 2-3 for a bunch of videos
#
# 5. on your google drive, create a directory disasters, then create subdirectories disasters/videofile and disasters/frames
#
# 6. upload all the videos to disasters/videofile ('/content/GDrive/My Drive/disasters/videofile/')
#
# 7. run the rest of this code

# %%
import cv2
import os

# %%
from google.colab import drive
drive.mount('/content/GDrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/GDrive/

# %%
# function to create images from videos

def create_stills(videoPath, seconds):
  print(videoPath)
  print(os.path.isfile(videoPath))
  vidcap = cv2.VideoCapture(videoPath)
  count = 0
  success = True
  fps = int(vidcap.get(cv2.CAP_PROP_FPS))
  print('frames per second is:', fps)
  while success:
      success,image = vidcap.read()
      if count%(seconds*fps) == 0 :
         cv2.imwrite('/content/GDrive/Shared drives/Team_576/disasters/frames/{}_{}.jpg'.format(shortName, count),image)
         print('successfully written frame')
      count+=1
  print('Images from video complete')

# %%
# Set parameters.

#Path to folder with videos 
videoDir = '/content/GDrive/Shared drives/Team_576/disasters/videofile/videos4/' 

#Make list of video files
video_files = os.listdir(videoDir)
print(video_files)

#Take a still every ___ seconds?
seconds = 5
# Out:
# ['Crowds  - ACL 2017.mp4']

# %%
# excute function to create images from all videos in the videofile directory on your Google Drive

for nameOfVideo in video_files:
  shortName = nameOfVideo.split('.')[0]
  print(shortName)
  videoPath = videoDir + nameOfVideo
  create_stills(videoPath, seconds)
print('All videos completed')
# Out:
# Crowds  - ACL 2017
# /content/GDrive/Shared drives/Team_576/disasters/videofile/videos4/Crowds  - ACL 2017.mp4
# True
# frames per second is: 23
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# successfully written frame
# ...
